# %% [markdown]
# # Rough Work for Individual Submission (all relevant things copied to the main document)

# %%
#attach packages to work with data
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
#source("cleanup.R")

# %% [markdown]
# ## opening files, making them tidy

# %%
#open files for descriptive summaries
players_data = read_csv("players.csv")
sessions_data = read_csv("sessions.csv")

players_data
sessions_data

# %%
sessions_wrangled = sessions_data |>
    separate(start_time, into = c("start_date", "start_time"), sep = " ") |>
    mutate(start_date = as.Date(start_date)) |>
    separate(end_time, into = c("end_date", "end_time"), sep = " ") |>
    mutate(end_date = as.Date(end_date))

sessions_wrangled

# %% [markdown]
# ## Getting descriptive summaries of datasets

# %%
#players_data
players_summary = players_data |>
    summary()
players_summary

experience_types = unique(players_data$experience) #$ access unique values from experience in players_data
experience_types

# %% [markdown]
# players_data summary
# - number of observations: 196
# - summary statistics (to 2 decimal places), played_hours variable (hours):
#   - min: 0.00
#   - 1st quartile: 0.00
#   - median: 0.10
#   - mean: 5.85
#   - 3rd quartile: 0.60
#   - max: 223.10
# - summary statistics (to 2 decimal places), age variable:
#   - min: 9.00
#   - 1st quartile: 17.00
#   - median: 19.00
#   - mean: 21.14
#   - 3rd quartile: 22.75
#   - max: 58.00
#   - NA's: 2 (meaning two players decided not to share their age)
# - number of variables: 7
# - name/type of variables and what they mean
#   - experience: character variable, 5 categories ("Pro", "Veteran", "Amateur", "Regular", "Beginner") based on how much experience the player has with minecraft
#   - subscribe: logical variable, returns "TRUE" or "FALSE" depending if the player is currently subscribed to
