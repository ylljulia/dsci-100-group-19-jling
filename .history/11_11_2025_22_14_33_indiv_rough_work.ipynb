# %% [markdown]
# # Rough Work for Individual Submission (all relavant things copied to the main document)

# %%
#attach packages to work with data
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
#source("cleanup.R")

# %%
##

# %%
#open files for descriptive summaries
players_data = read_csv("players.csv")
sessions_data = read_csv("sessions.csv")

players_data
sessions_data
